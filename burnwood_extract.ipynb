# %%
import pandas as pd
import numpy as np
import re
import time

# %%
print("Loading Observation Dataframe...")
alpha = time.time()

df_iawa = pd.read_excel("InsideWood_Africa_1-06-2023.xlsx", engine="openpyxl", header=0, na_filter=False).astype("str")
df_cepam = pd.read_excel("CEPAM_feature_net.xlsx", engine="openpyxl", sheet_name="CEPAM", header=2, na_filter=False).astype("str")

print(f"Dataframes loading time : {time.time() - alpha} seconds")
# Out:
# Loading Observation Dataframe...
# Dataframes loading time : 1.0790698528289795 seconds

# %%
def manual_read_csv(filepath, enc, sep):
    with open(filepath, "r", encoding=enc) as csv_file:
        i = 0
        size = 0
        col_name = []
        data = []
        for line in csv_file:
            line = line.replace("\n", "")
            if i == 0:
                i += 1
                col_name = line.split(sep)
                size = len(col_name)
                continue
            line_spread = line.split(sep)
            if size < len(line_spread):
                line_spread
                raise("This line is not suitable")
            data.append(line_spread)
            i += 1
    return pd.DataFrame(data, columns=col_name)

# %%
# POWO generation for graph
print("Loading POWO Dataframe...")
alpha = time.time()

df_powo_taxa = pd.read_csv("recent_db/wcvp_taxon.csv", header=0, sep="|", encoding="UTF-8").astype("str")
df_powo_name = manual_read_csv("recent_db/Only/wcvp_names.csv","UTF-8", "|").astype("str")
df_dist = pd.read_csv("recent_db/Only/wcvp_distribution.csv", header=0, sep="|", encoding="UTF-8").astype("str")

old_df_powo = pd.read_csv("special_issue/wcvp_names.csv", header=0, sep="|", encoding="UTF-8").astype("str")
old_df_dist = pd.read_csv("special_issue/wcvp_distribution.csv", header=0, sep="|", encoding="UTF-8").astype("str")

print(f"Dataframes loading time : {time.time() - alpha} seconds")
# Out:
# Loading POWO Dataframe...
# Dataframes loading time : 48.67000365257263 seconds

# %%
reduced_data = []
ignore_data = []
reduced_label = ["plant_name_id", "parent_id", "accepted_plant_name_id", "family", "genus", "taxon_name", "taxon_status", "ipni_id"]
filter_list = ["Accepted", "Synonym", "Unplaced"]
filter_powo = df_powo_name[df_powo_name["taxon_status"].isin(filter_list)]

# %%
iawa_label = ["iawa_family", "iawa_taxon", "iawa_usual_name", "accepted_id", "powo_family", "powo_genus", "powo_taxon", "powo_authors",
         "zone"]

errors_label = ["taxon", "iawa_line", "status"]
errors = []
BUG = None

# %%
def extract_iawa_information(row):
    family = ""
    original_string = df_iawa["Taxa"][row].replace("?", "")
    #print(original_string)
    for x in original_string.split("|"):
        x = x.replace("Synonym:", "")
        family = re.search("[A-Z][A-Z]+\s[A-Z][A-Z]+|[A-Z][A-Z]+", x).group(0)
        genre = re.search(
            "[A-Z][a-z]+\s(spp\.|sp\.|SPP\.|SP\.|sect\.)|[A-Z][a-z]+\s[a-z]+\s(subsp\.|var\.)\s[a-z]+|[A-Z][a-z]+\s(aff\.|cf\.)\s[a-z\-]+|[A-Z][a-z]+\s[a-z\-]+|[A-Z][a-z]+\.*", x).group(0)
        if re.search("\([A-Z][A-Z,\s]+\)", x):
            usual_name = re.search("\([A-Z][A-Z,\s]+\)", x).group(0)
        else:
            usual_name = ""
        return family, genre, usual_name, original_string

# %%
def get_plant_by_id(plant_id, df, plant):
    p1 = df[df["plant_name_id"].values == plant_id]
    
    if p1.empty:
        raise Exception(f"{plant}\nNo match id found for {plant_id} value type {type(plant_id)} test: {np.nan == plant_id}...")
    return p1['plant_name_id'].values[0], p1['family'].values[0], p1['genus'].values[0], p1['taxon_name'].values[0], p1['taxon_authors'].values[0]

# %%
def get_region_by_id(plant_id, df):
    r1 = df[df["plant_name_id"] == plant_id]
    return r1["continent"].values, r1["region"].values, r1["area"].values

# %%
def get_id_by_taxon2(taxon, df, org_str):
    matches = [" sp.", " spp.", " SPP.", " SP.", " group", "subgrp", "sect.", " SPP", "SP", " spp",]
    taxon = taxon.replace(" cf. ", " ").replace(" aff. ", " ").strip()
    category = "taxon_name"
    if any([x in taxon for x in matches]):
        for x in matches:
            taxon = taxon.replace(x, "").strip()
    
    reduced_taxon_df = df[df["taxon_name"] == taxon].sort_values(by=['taxon_status'])
    if len(reduced_taxon_df) > 1:
        waiting = []
        synonyms = []
        for row in reduced_taxon_df.index:
            
            status = reduced_taxon_df["taxon_status"][row]
            pl_id = reduced_taxon_df["plant_name_id"][row]
            pl_name = reduced_taxon_df["taxon_name"][row]
            pl_accepted = reduced_taxon_df["accepted_plant_name_id"][row]
            
            if status == "Accepted":
                location = df_dist[df_dist["plant_name_id"] == pl_id]["continent"].values.tolist()
                if "AFRICA" in location:
                    return pl_id
            
            if status == "Synonym":
                parent_status = df[df["plant_name_id"] == pl_accepted]["taxon_status"].values
                parent_id = pl_accepted
                parent_name = df[df["plant_name_id"] == pl_accepted]["taxon_name"].values
                location = df_dist[df_dist["plant_locality_id"] == parent_id]["continent"].values.tolist()
                if parent_status == "Accepted" and "AFRICA" in location:
                    synonyms.append(pl_id)
            
            if status not in ["Accepted", "Synonym"]:
                parent_status = df[df["plant_name_id"] == pl_accepted]["taxon_status"].values
                parent_id = pl_accepted
                parent_name = df[df["plant_name_id"] == pl_accepted]["taxon_name"].values
                location = df_dist[df_dist["plant_locality_id"] == parent_id]["continent"].values.tolist()
                if parent_status == "Accepted" and "AFRICA" in location:
                    waiting.append(parent_id)
        
        if len(synonyms) >= 1:
            return synonyms[0]
        
        if len(waiting) > 1:
            print(waiting)
        if waiting == []:
            print(taxon)
            errors.append([taxon, org_str, "Pas en Afrique"])
            return None
        return waiting[0]
    
    accepted_id_search = df[df[category] == taxon]['accepted_plant_name_id'].values
    plant_id = df[df[category] == taxon]['plant_name_id'].values
    if accepted_id_search.size == 0 and plant_id.size == 0:
        errors.append([taxon, org_str, "Pas trouvé dans la base"])
        return None
    
    status = df[df[category] == taxon]['taxon_status'].values[0]
    if not accepted_id_search and status != "Accepted":
        print(f"No accepted id for {taxon}")
        return plant_id

    status = df[df["plant_name_id"].values == accepted_id_search]["plant_name_id"].tolist()[0]
    
    while len(status) > 0 and status != "Accepted":
        if status != "Accepted":
            print(f"{accepted_id_search} status : {status}")
        accepted_id_search = df[df["plant_name_id"].values == accepted_id_search]['accepted_plant_name_id'].tolist()[0]
        status = df[df["plant_name_id"].values == accepted_id_search]["taxon_status"].tolist()[0]

    return accepted_id_search

# %%
# Execution
errors = []
extract_family = []
extract_genre = []
extract_usual_name = []
new_iawa = []

ignore_features = [
    "52 - <= 350 Âµm",
    "53 - 350 - 800 Âµm",
    "54 - >= 800 Âµm",
    "59MH - Wood vesselless",
    "60 - Vascular / vasicentric tracheids present",
    "67MH - Parenchyma-like fibre bands alternating with ordinary fibres",
    "71MH - <= 900 Âµm",
    "72MH - 900-1600 Âµm",
    "73MH - >= 1600 Âµm",
    "95MH - Unlignified parenchyma"
                  ]

# %%
def get_id_by_taxon(taxon, df, org_str):
    matches = [" sp.", " spp.", " SPP.", " SP.", " group", "subgrp", "sect.", " SPP", "SP", " spp",]
    taxon = taxon.replace(" cf. ", " ").replace(" aff. ", " ").strip()
    category = "taxon_name"
    if any([x in taxon for x in matches]):
        for x in matches:
            taxon = taxon.replace(x, "").strip()
    
    reduced_df = df[df["taxon_name"] == taxon]
    if reduced_df.empty:
        print([taxon, org_str, "Not found in database"])
        errors.append([taxon, org_str, "Not found in database"])
    for row in reduced_df.index:
        if df[df["plant_name_id"] == df["accepted_plant_name_id"][row]].index.size == 1:
            status = df[df["plant_name_id"] == df["accepted_plant_name_id"][row]]["taxon_status"].values[0]
            accepted_id = df[df["plant_name_id"] == df["accepted_plant_name_id"][row]]["plant_name_id"].values[0]
            dist_found = df_dist[df_dist["plant_name_id"] == accepted_id]
            if not dist_found[dist_found["continent"] == "AFRICA"].empty:
                return accepted_id
    print([taxon, org_str, "Taxa not in AFRICA"])
    errors.append([taxon, org_str, "Taxa not in AFRICA"])

# %%
alpha = time.time()
print("Starting IAWA extraction")
iawa_label = ["InsideWood_line", "accepted_id", "powo_family", "powo_genus", "powo_taxon", "powo_authors",
         "zone"]

for column_label in df_iawa.columns[1:]:
    if column_label == "163MH - Vitreous silica":
            break
    if column_label not in ignore_features:
        iawa_label.append(column_label)

for row in df_iawa.index:
    family, genre, usual_name, original_string = extract_iawa_information(row)
    accepted_id = get_id_by_taxon(genre, df_powo_name, original_string)
    if accepted_id:
        plant_id, accepted_family, accepted_genus, accepted_taxon, accepted_authors = get_plant_by_id(accepted_id, df_powo_name, original_string)
        continent, region, area = get_region_by_id(accepted_id, df_dist)
    else:
        plant_id, accepted_family, accepted_genus, accepted_taxon, accepted_authors = "", family, genre.split(" ")[0], genre.split(" ")[1], ""
    
    data = []
    for column_label in list(df_iawa.columns[1:]):
        if column_label == "163MH - Vitreous silica":
            break
        if column_label not in ignore_features:
            v = df_iawa[column_label][row]
            if isinstance(v, int):
                data.append("3")
            elif "v" in v:
                data.append("2")
            elif "?" in v:
                data.append("1")
            else:
                data.append("0")
            
    
    zone = []
    for x,y,z in zip(continent, region, area):
        zone.append(f"({x},{y},{z})")
    temp = [df_iawa["Taxa"][row],
                    plant_id, accepted_family, accepted_genus, accepted_taxon, accepted_authors,
                    "".join(zone)]
    temp.extend(data)
    new_iawa.append(temp)

print(f"Extraction done in {time.time() - alpha} seconds...")
pd.DataFrame(errors, columns=errors_label).to_csv("errors_iawa.csv", index=False, encoding="utf-8")
pd.DataFrame(new_iawa, columns=iawa_label).to_csv("generated_iawa.csv", index=False, encoding="utf-8", sep=";")

#print(to_extract)
# Out:
# Starting IAWA extraction
# ['Lindackeria laurina', 'ACHARIACEAE Lindackeria laurina C. Presl', 'Taxa not in AFRICA']
# ['Anaxagorea inundata', 'ANNONACEAE Anaxagorea inundata P. E. Berry & R. B. Miller', 'Taxa not in AFRICA']
# ['Stephanotis abyssinica', 'APOCYNACEAE Stephanotis abyssinica', 'Not found in database']
# ['Stephanotis abyssinica', 'APOCYNACEAE Stephanotis abyssinica', 'Taxa not in AFRICA']
# ['Schefflera', 'ARALIACEAE Schefflera group D2', 'Taxa not in AFRICA']
# ['Dacryodes', 'BURSERACEAE Dacryodes SPP. (KEDONDONG)', 'Taxa not in AFRICA']
# ['Celtis philippensis', 'CANNABACEAE Celtis philippensis Blanco (HARD CELTIS)', 'Taxa not in AFRICA']
# ['Celtis philippensis', 'CANNABACEAE Celtis philippensis Blanco (HARD CELTIS)', 'Taxa not in AFRICA']
# ['Erythrostelechia acuminata', 'CELASTRACEAE Erythrostelechia acuminata Capuron', 'Not found in database']
# ['Erythrostelechia acuminata', 'CELASTRACEAE Erythrostelechia acuminata Capuron', 'Taxa not in AFRICA']
# ['Atuna excelsa', 'CHRYSOBALANACEAE Atuna excelsa (Jack) Kosterm. (MERBATU, MUBURA, SOUGUE)|Synonym: CHRYSOBALANACEAE Parinari asperula Miq.', 'Taxa not in AFRICA']
# ['Calopyxis malifolia', 'COMBRETACEAE Calopyxis malifolia', 'Taxa not in AFRICA']
# ['Delonix edule', 'LEGUMINOSAE CAESALPINIOIDEAE Delonix edule (H.Perrier) Babineau & Bruneau|Synonym: LEGUMINOSAE CAESALPINIOIDEAE Lemuropisum edule (Baker) Kuntze', 'Not found in database']
# ['Delonix edule', 'LEGUMINOSAE CAESALPINIOIDEAE Delonix edule (H.Perrier) Babineau & Bruneau|Synonym: LEGUMINOSAE CAESALPINIOIDEAE Lemuropisum edule (Baker) Kuntze', 'Taxa not in AFRICA']
# ['Vachellia gerrardii', 'LEGUMINOSAE MIMOSOIDEAE Vachellia gerrardii (Benth.) P.J.H.Hurter|Synonym: LEGUMINOSAE MIMOSOIDEAE Acacia gerrardi Benth.', 'Not found in database']
# ['Vachellia gerrardii', 'LEGUMINOSAE MIMOSOIDEAE Vachellia gerrardii (Benth.) P.J.H.Hurter|Synonym: LEGUMINOSAE MIMOSOIDEAE Acacia gerrardi Benth.', 'Taxa not in AFRICA']
# ['Dombeya acerifolia', 'MALVACEAE DOMBEYOIDEAE Dombeya acerifolia Baker', 'Taxa not in AFRICA']
# ['Grewia androyensis', 'MALVACEAE GREWIOIDEAE Grewia androyensis Capuron', 'Not found in database']
# ['Grewia androyensis', 'MALVACEAE GREWIOIDEAE Grewia androyensis Capuron', 'Taxa not in AFRICA']
# ['Grewia barorum', 'MALVACEAE GREWIOIDEAE Grewia barorum Capuron', 'Not found in database']
# ['Grewia barorum', 'MALVACEAE GREWIOIDEAE Grewia barorum Capuron', 'Taxa not in AFRICA']
# ['Grewia damine', 'MALVACEAE GREWIOIDEAE Grewia damine Gaertn. (BASTARD BRANDY BUSH, DONKEY BERRY, FALSE BRANDY BUSH, GREUVIER, GRÃ‰VIER BICOLORE)|Synonym: MALVACEAE GREWIOIDEAE Grewia bicolor Juss.', 'Taxa not in AFRICA']
# ['Grewia maintiranensis', 'MALVACEAE GREWIOIDEAE Grewia maintiranensis Capuron', 'Not found in database']
# ['Grewia maintiranensis', 'MALVACEAE GREWIOIDEAE Grewia maintiranensis Capuron', 'Taxa not in AFRICA']
# ['Grewia nucifera', 'MALVACEAE GREWIOIDEAE Grewia nucifera Capuron', 'Not found in database']
# ['Grewia nucifera', 'MALVACEAE GREWIOIDEAE Grewia nucifera Capuron', 'Taxa not in AFRICA']
# ['Marcgravia brownei', 'MARCGRAVIACEAE Marcgravia brownei', 'Taxa not in AFRICA']
# ['Pisonia umbellifera', 'NYCTAGINACEAE Pisonia umbellifera (J.R. Forst. & G. Forst.) Seem. (BIRD-CATCHER TREE, PAPALA KEPAU, PARA-PARA)|Synonym: NYCTAGINACEAE Pisonia excelsa Blume', 'Taxa not in AFRICA']
# ['Chionanthus', 'OLEACEAE Chionanthus subgrp A I', 'Taxa not in AFRICA']
# ['Hauya elegans', 'ONAGRACEAE Hauya elegans', 'Taxa not in AFRICA']
# ['Gardenia resinifera', 'RUBIACEAE Gardenia resinifera Roth (BRILLIANT GARDENIA, CAMBI RESIN TREE, DIKAMALI)|Synonym: RUBIACEAE Gardenia lucida Roxb.', 'Taxa not in AFRICA']
# ['Afraegle asso', 'RUTACEAE Afraegle asso Engl.', 'Taxa not in AFRICA']
# ['Chloroxylon faho', 'RUTACEAE Chloroxylon faho R. Capuron (SATINWOOD)', 'Taxa not in AFRICA']
# ['Melicope fatraina', 'RUTACEAE Melicope fatraina (H. Perrier) T.G. Hartley|Synonym: RUTACEAE Evodia fatraina (Baker) Kuntze', 'Taxa not in AFRICA']
# ['Bembiciopsis uniflora', 'SALICACEAE Bembiciopsis uniflora H. Perrier', 'Taxa not in AFRICA']
# ['Allophylus cobbe', 'SAPINDACEAE Allophylus cobbe (L.) Raeuschel', 'Taxa not in AFRICA']
# ['Allophylus cobbe', 'SAPINDACEAE Allophylus cobbe (L.) Raeuschel', 'Taxa not in AFRICA']
# ['Pouteria cuspidata', 'SAPOTACEAE Pouteria cuspidata (A.DC.) Baehni (ANIEGRE)|Synonym: SAPOTACEAE Aningeria robusta|Synonym: SAPOTACEAE Pouteria cuspidata (A.DC.) Baehni subsp. robusta (Mart. & Eichler ex Miq.) T.D.Penn.|Synonym: SAPOTACEAE Pouteria robusta (Mart. & Eichler ex Miq.) Eyma', 'Taxa not in AFRICA']
# ['Cayratia', 'VITACEAE Cayratia spp', 'Taxa not in AFRICA']
# Extraction done in 2039.5018196105957 seconds...

# %%
pd.DataFrame(errors, columns=errors_label).to_csv("errors_iawa.csv", index=False, encoding="utf-8")
pd.DataFrame(new_iawa, columns=iawa_label).to_csv("generated_iawa.csv", index=False, encoding="utf-8", sep=";")

# %%
ignore_features = [
    "52 - <= 350 Âµm",
    "53 - 350 - 800 Âµm",
    "54 - >= 800 Âµm",
    "59MH - Wood vesselless",
    "60 - Vascular / vasicentric tracheids present",
    "67MH - Parenchyma-like fibre bands alternating with ordinary fibres",
    "71MH - <= 900 Âµm",
    "72MH - 900-1600 Âµm",
    "73MH - >= 1600 Âµm",
    "95MH - Unlignified parenchyma"
                  ]

df_cepam = pd.read_excel("generated_cepam_5-07-2023.xlsx", header=0,na_filter=False)

cepam_label = ["id_sample", "cepam_family", "cepam_genus", "cepam_taxon",
               "accepted_id", "powo_family", "powo_genus", "powo_taxon", "powo_authors",
         "zone"]

for column_label in df_cepam.columns[10:]:
    if column_label == "163MH - Vitreous silica":
            break
    if column_label not in ignore_features:
        cepam_label.append(column_label)
        
new_cepam = []
errors = []

alpha = time.time()
print("Starting CEPAM extraction")
for row in df_cepam.index:
    id_sample, family, genus, taxon = df_cepam["id_sample"][row], df_cepam["cepam_family"][row], df_cepam["cepam_genus"][row], df_cepam["cepam_taxon"][row]
    taxon = taxon.replace(" cf ", " cf. ")
    accepted_id = get_id_by_taxon(taxon, df_powo_name, f"{family} {genus} {taxon} {id_sample}")
    if not accepted_id:
        print(f" {id_sample} => {family} {genus} {taxon}")
        raise("Error, taxon not found in POWO")
    plant_id, accepted_family, accepted_genus, accepted_taxon, accepted_authors = get_plant_by_id(accepted_id, df_powo_name, f"{family} {genus} {taxon} {id_sample}")
    continent, region, area = get_region_by_id(accepted_id, df_dist)
    
    data = []
    for column_label in list(df_cepam.columns[10:]):
        if column_label == "163MH - Vitreous silica":
            break
        if column_label not in ignore_features:
            v = df_cepam[column_label][row]
            if isinstance(v, int):
                data.append("3")
            elif "v" in v:
                data.append("2")
            elif "?" in v:
                data.append("1")
            else:
                data.append("0")
                
    zone = []
    for x,y,z in zip(continent, region, area):
        zone.append(f"({x},{y},{z})")
    temp = [id_sample, family, genus, taxon,
                    plant_id, accepted_family, accepted_genus, accepted_taxon, accepted_authors,
                    "".join(zone)]
    temp.extend(data)
    new_cepam.append(temp)

print(f"Extraction done in {time.time() - alpha} seconds...")
pd.DataFrame(errors, columns=errors_label).to_csv("errors_cepam.csv", index=False, encoding="utf-8")
pd.DataFrame(new_cepam, columns=cepam_label).to_csv("generated_cepam.csv", index=False, encoding="utf-8", sep=";")
# Out:
# Starting CEPAM extraction
# Extraction done in 52.531033992767334 seconds...

# %%
pd.DataFrame(errors, columns=errors_label).to_csv("errors_cepam.csv", index=False, encoding="utf-8")
pd.DataFrame(new_cepam, columns=cepam_label).to_csv("generated_cepam.csv", index=False, encoding="utf-8", sep=";")

# %%
genus = re.search(
    "[A-Z][a-z]+\s(spp\.|sp\.)|[A-Z][a-z]+\s[a-z]+\s(subsp\.|cf\.|var\.)+\s[a-z]+|[A-Z][a-z]+\s[a-z\-]+|[A-Z][a-z]+",
          "LECYTHIDACEAE Oubanguia sp.").group(0)
print(genus)
# Out:
# Oubanguia sp.

# %%
df_cepam = pd.read_excel("CEPAM_feature_net.xlsx", sheet_name="CEPAM", header=2,na_filter=False)

# %%
experiment = list(df_cepam.columns)[4:]
for x in experiment:
    print(x)
    if len(x.split("-", 1)) > 1:
        number, name = x.split("-", 1)
    else:
        number, name = x.split(chr(8211),1)
    print(f"{number} : named {name}")
# Out:
# 1 - Growth ring boundaries distinct
# 1  : named  Growth ring boundaries distinct
# 2 - Growth ring boundaries indistinct or absent
# 2  : named  Growth ring boundaries indistinct or absent
# 3 - Wood ring-porous
# 3  : named  Wood ring-porous
# 4 - Wood semi-ring-porous
# 4  : named  Wood semi-ring-porous
# 5 - Wood diffuse-porous
# 5  : named  Wood diffuse-porous
# 6 - Vessels in tangential bands
# 6  : named  Vessels in tangential bands
# 7 - Vessels in diagonal and / or radial pattern
# 7  : named  Vessels in diagonal and / or radial pattern
# 8 - Vessels in dendritic pattern
# 8  : named  Vessels in dendritic pattern
# 9 - Vessels exclusively solitary (90% or more)
# 9  : named  Vessels exclusively solitary (90% or more)
# 10 - Vessels in radial multiples of 4 or more common
# 10  : named  Vessels in radial multiples of 4 or more common
# 11 - Vessel clusters common
# 11  : named  Vessel clusters common
# 12 - Solitary vessel outline angular
# 12  : named  Solitary vessel outline angular
# 13 - Simple perforation plates
# 13  : named  Simple perforation plates
# 14 - Scalariform perforation plates
# 14  : named  Scalariform perforation plates
# 15 - Scalariform perforation plates with ≤ 10 bars
# 15  : named  Scalariform perforation plates with ≤ 10 bars
# 16 - Scalariform perforation plates with 10 - 20 bars
# 16  : named  Scalariform perforation plates with 10 - 20 bars
# 17 - Scalariform perforation plates with 20 - 40 bars
# 17  : named  Scalariform perforation plates with 20 - 40 bars
# 18 - Scalariform perforation plates with ≥ 40 bars
# 18  : named  Scalariform perforation plates with ≥ 40 bars
# 19 - Reticulate, foraminate, and / or other types of multiple perforation plates
# 19  : named  Reticulate, foraminate, and / or other types of multiple perforation plates
# 20 - Intervessel pits scalariform
# 20  : named  Intervessel pits scalariform
# 21 - Intervessel pits opposite
# 21  : named  Intervessel pits opposite
# 22 - Intervessel pits alternate
# 22  : named  Intervessel pits alternate
# 23 - Shape of alternate pits polygonal
# 23  : named  Shape of alternate pits polygonal
# 24 - Minute ≤ 4 µm
# 24  : named  Minute ≤ 4 µm
# 25 - Small 4 - 7 µm
# 25  : named  Small 4 - 7 µm
# 26 - Medium 7 - 10 µm
# 26  : named  Medium 7 - 10 µm
# 27 – Large ≥ 10 µm
# 27  : named  Large ≥ 10 µm
# 29 - Vestured pits
# 29  : named  Vestured pits
# 30 - Vessel-ray pits with distinct borders; similar to intervessel pits in size and shape throughout the ray cell
# 30  : named  Vessel-ray pits with distinct borders; similar to intervessel pits in size and shape throughout the ray cell
# 31 - Vessel-ray pits with much reduced borders to apparently simple: pits rounded or angular
# 31  : named  Vessel-ray pits with much reduced borders to apparently simple: pits rounded or angular
# 32 - Vessel-ray pits with much reduced borders to apparently simple: pits horizontal (scalariform, gash-like) to vertical (palisade)
# 32  : named  Vessel-ray pits with much reduced borders to apparently simple: pits horizontal (scalariform, gash-like) to vertical (palisade)
# 33 - Vessel-ray pits of two distinct sizes or types in the same ray cell
# 33  : named  Vessel-ray pits of two distinct sizes or types in the same ray cell
# 34 - Vessel-ray pits unilaterally compound and coarse (over 10 µm)
# 34  : named  Vessel-ray pits unilaterally compound and coarse (over 10 µm)
# 35 - Vessel-ray pits restricted to marginal rows
# 35  : named  Vessel-ray pits restricted to marginal rows
# 36 - Helical thickenings in vessel elements present
# 36  : named  Helical thickenings in vessel elements present
# 37 - Helical thickenings throughout body of vessel element
# 37  : named  Helical thickenings throughout body of vessel element
# 38 - Helical thickenings only in vessel element tails
# 38  : named  Helical thickenings only in vessel element tails
# 39 - Helical thickenings only in narrower vessel elements
# 39  : named  Helical thickenings only in narrower vessel elements
# 40 - ≤ 50 µm
# 40  : named  ≤ 50 µm
# 41 - 50 - 100 µm
# 41  : named  50 - 100 µm
# 42 - 100 - 200 µm
# 42  : named  100 - 200 µm
# 43 -  ≥  200 µm
# 43  : named   ≥  200 µm
# 45 - Vessels of two distinct diameter classes, wood not ring-porous
# 45  : named  Vessels of two distinct diameter classes, wood not ring-porous
# 46 - ≤ 5 vessels per square millimetre
# 46  : named  ≤ 5 vessels per square millimetre
# 47 - 5 - 20 vessels per square millimetre
# 47  : named  5 - 20 vessels per square millimetre
# 48 - 20 - 40 vessels per square millimetre
# 48  : named  20 - 40 vessels per square millimetre
# 49 - 40 - 100 vessels per square millimetre
# 49  : named  40 - 100 vessels per square millimetre
# 50 - ≥ 100 vessels per square millimetre
# 50  : named  ≥ 100 vessels per square millimetre
# 56 - Tyloses common
# 56  : named  Tyloses common
# 57 - Tyloses sclerotic
# 57  : named  Tyloses sclerotic
# 58 - Gums and other deposits in heartwood vessels
# 58  : named  Gums and other deposits in heartwood vessels
# 59 - Wood vesselless
# 59  : named  Wood vesselless
# 60 - Vascular / vasicentric tracheids present
# 60  : named  Vascular / vasicentric tracheids present
# 61 - Fibres with simple to minutely bordered pits
# 61  : named  Fibres with simple to minutely bordered pits
# 62 - Fibres with distinctly bordered pits
# 62  : named  Fibres with distinctly bordered pits
# 63 - Fibre pits common in both radial and tangential walls
# 63  : named  Fibre pits common in both radial and tangential walls
# 64 - Helical thickenings in ground tissue fibres
# 64  : named  Helical thickenings in ground tissue fibres
# 65 - Septate fibres present
# 65  : named  Septate fibres present
# 66 - Non-septate fibres present
# 66  : named  Non-septate fibres present
# 67 - Parenchyma-like fibre bands alternating with ordinary fibres
# 67  : named  Parenchyma-like fibre bands alternating with ordinary fibres
# 68 - Fibres very thin-walled
# 68  : named  Fibres very thin-walled
# 69 - Fibres thin- to thick-walled
# 69  : named  Fibres thin- to thick-walled
# 70 - Fibres very thick-walled
# 70  : named  Fibres very thick-walled
# 75 - Axial parenchyma absent or extremely rare
# 75  : named  Axial parenchyma absent or extremely rare
# 76 - Axial parenchyma diffuse
# 76  : named  Axial parenchyma diffuse
# 77 - Axial parenchyma diffuse-in-aggregates
# 77  : named  Axial parenchyma diffuse-in-aggregates
# 78 - Axial parenchyma scanty paratracheal
# 78  : named  Axial parenchyma scanty paratracheal
# 79 - Axial parenchyma vasicentric
# 79  : named  Axial parenchyma vasicentric
# 80 - Axial parenchyma aliform
# 80  : named  Axial parenchyma aliform
# 81 - Axial parenchyma lozenge-aliform
# 81  : named  Axial parenchyma lozenge-aliform
# 82 - Axial parenchyma winged-aliform
# 82  : named  Axial parenchyma winged-aliform
# 83 - Axial parenchyma confluent
# 83  : named  Axial parenchyma confluent
# 84 - Axial parenchyma unilateral paratracheal
# 84  : named  Axial parenchyma unilateral paratracheal
# 85 - Axial parenchyma bands more than three cells wide
# 85  : named  Axial parenchyma bands more than three cells wide
# 86 - Axial parenchyma in narrow bands or lines up to three cells wide
# 86  : named  Axial parenchyma in narrow bands or lines up to three cells wide
# 87 - Axial parenchyma reticulate
# 87  : named  Axial parenchyma reticulate
# 88 - Axial parenchyma scalariform
# 88  : named  Axial parenchyma scalariform
# 89 - Axial parenchyma in marginal or in seemingly marginal bands
# 89  : named  Axial parenchyma in marginal or in seemingly marginal bands
# 90 - Fusiform parenchyma cells
# 90  : named  Fusiform parenchyma cells
# 91 - Two cells per parenchyma strand
# 91  : named  Two cells per parenchyma strand
# 92 - Four (3-4) cells per parenchyma strand
# 92  : named  Four (3-4) cells per parenchyma strand
# 93 - Eight (5-8) cells per parenchyma strand
# 93  : named  Eight (5-8) cells per parenchyma strand
# 94 - Over eight cells per parenchyma strand
# 94  : named  Over eight cells per parenchyma strand
# 95 - Unlignified parenchyma
# 95  : named  Unlignified parenchyma
# 96 - Rays exclusively uniseriate
# 96  : named  Rays exclusively uniseriate
# 97 - Ray width 1 to 3 cells
# 97  : named  Ray width 1 to 3 cells
# 98 - Larger rays commonly 4 - to 10 seriate
# 98  : named  Larger rays commonly 4 - to 10 seriate
# 99 - Larger rays commonly > 10-seriate
# 99  : named  Larger rays commonly > 10-seriate
# 100 - Rays with multiseriate portion(s) as wide as uniseriate portions
# 100  : named  Rays with multiseriate portion(s) as wide as uniseriate portions
# 101 - Aggregate rays
# 101  : named  Aggregate rays
# 102 - Ray height > 1 mm
# 102  : named  Ray height > 1 mm
# 103 - Rays of two distinct sizes
# 103  : named  Rays of two distinct sizes
# 104 - All ray cells procumbent
# 104  : named  All ray cells procumbent
# 105 - All ray cells upright and / or square
# 105  : named  All ray cells upright and / or square
# 106 - Body ray cells procumbent with one row of upright and / or square marginal cells
# 106  : named  Body ray cells procumbent with one row of upright and / or square marginal cells
# 107 - Body ray cells procumbent with mostly 2-4 rows of upright and / or square marginal cells
# 107  : named  Body ray cells procumbent with mostly 2-4 rows of upright and / or square marginal cells
# 108 - Body ray cells procumbent with over 4 rows of upright and / or square marginal cells
# 108  : named  Body ray cells procumbent with over 4 rows of upright and / or square marginal cells
# 109 - Rays with procumbent, square and upright cells mixed throughout the ray
# 109  : named  Rays with procumbent, square and upright cells mixed throughout the ray
# 110 - Sheath cells
# 110  : named  Sheath cells
# 111 - Tile cells
# 111  : named  Tile cells
# 112 - Perforated ray cells
# 112  : named  Perforated ray cells
# 113 - Disjunctive ray parenchyma cell walls
# 113  : named  Disjunctive ray parenchyma cell walls
# 114 - ≤ 4 / mm
# 114  : named  ≤ 4 / mm
# 115 - 4-12 / mm
# 115  : named  4-12 / mm
# 116 - ≥ 12 /mm
# 116  : named  ≥ 12 /mm
# 117 - Wood rayless
# 117  : named  Wood rayless
# 118 - All rays storied
# 118  : named  All rays storied
# 119 - Low rays storied, high rays non-storied.
# 119  : named  Low rays storied, high rays non-storied.
# 120 - Axial parenchyma and / or vessel elements storied
# 120  : named  Axial parenchyma and / or vessel elements storied
# 121 - Fibres storied
# 121  : named  Fibres storied
# 122 - Rays and / or axial elements irregularly storied
# 122  : named  Rays and / or axial elements irregularly storied
# 124 - Oil and / or mucilage cells associated with ray parenchyma
# 124  : named  Oil and / or mucilage cells associated with ray parenchyma
# 125 - Oil and / or mucilage cells associated with axial parenchyma
# 125  : named  Oil and / or mucilage cells associated with axial parenchyma
# 126 - Oil and / or mucilage cells present among fibres
# 126  : named  Oil and / or mucilage cells present among fibres
# 127 - Axial canals in long tangential lines
# 127  : named  Axial canals in long tangential lines
# 128 - Axial canals in short tangential lines
# 128  : named  Axial canals in short tangential lines
# 129 - Axial canals diffuse
# 129  : named  Axial canals diffuse
# 130 - Radial canals
# 130  : named  Radial canals
# 131 - Intercellular canals of traumatic origin
# 131  : named  Intercellular canals of traumatic origin
# 132 - Laticifers or tanniniferous tubes
# 132  : named  Laticifers or tanniniferous tubes
# 133 - Included phloem, concentric
# 133  : named  Included phloem, concentric
# 134 - Included phloem, diffuse
# 134  : named  Included phloem, diffuse
# 135 - Other cambial variants
# 135  : named  Other cambial variants
# 136 - Prismatic crystals present
# 136  : named  Prismatic crystals present
# 137 - Prismatic crystals in upright and / or square ray cells
# 137  : named  Prismatic crystals in upright and / or square ray cells
# 138 - Prismatic crystals in procumbent ray cells
# 138  : named  Prismatic crystals in procumbent ray cells
# 139 - Prismatic crystals in radial alignment in procumbent ray cells
# 139  : named  Prismatic crystals in radial alignment in procumbent ray cells
# 140 - Prismatic crystals in chambered upright and / or square ray cells
# 140  : named  Prismatic crystals in chambered upright and / or square ray cells
# 141 - Prismatic crystals in non-chambered axial parenchyma cells
# 141  : named  Prismatic crystals in non-chambered axial parenchyma cells
# 142 - Prismatic crystals in chambered axial parenchyma cells
# 142  : named  Prismatic crystals in chambered axial parenchyma cells
# 143 - Prismatic crystals in fibres
# 143  : named  Prismatic crystals in fibres
# 144 - Druses present
# 144  : named  Druses present
# 145 - Druses in ray parenchyma cells
# 145  : named  Druses in ray parenchyma cells
# 146 - Druses in axial parenchyma cells
# 146  : named  Druses in axial parenchyma cells
# 147 - Druses in fibres
# 147  : named  Druses in fibres
# 148 - Druses in chambered cells
# 148  : named  Druses in chambered cells
# 149 - Raphides
# 149  : named  Raphides
# 150 - Acicular crystals
# 150  : named  Acicular crystals
# 151 - Styloids and / or elongate crystals
# 151  : named  Styloids and / or elongate crystals
# 152 - Crystals of other shapes (mostly small)
# 152  : named  Crystals of other shapes (mostly small)
# 153 - Crystal sand
# 153  : named  Crystal sand
# 154 - More than one crystal of about the same size per cell or chamber
# 154  : named  More than one crystal of about the same size per cell or chamber
# 155 - Two distinct sizes of crystals per cell or chamber
# 155  : named  Two distinct sizes of crystals per cell or chamber
# 156 - Crystals in enlarged cells
# 156  : named  Crystals in enlarged cells
# 157 - Crystals in tyloses
# 157  : named  Crystals in tyloses
# 158 - Cystoliths
# 158  : named  Cystoliths
# 159 - Silica bodies present
# 159  : named  Silica bodies present
# 160 - Silica bodies in ray cells
# 160  : named  Silica bodies in ray cells
# 161 - Silica bodies in axial parenchyma cells
# 161  : named  Silica bodies in axial parenchyma cells
# 162 - Silica bodies in fibres
# 162  : named  Silica bodies in fibres

# %%
"27 – Large ≥ 10 µm".split("-")
print(ord("-"))
print(ord("27 – Large ≥ 10 µm"[3]))
# Out:
# 45
# 8211

# %%
list(df_iawa.columns[1:])
# Out:
# ['1 - Growth ring boundaries distinct',
#  '2 - Growth ring boundaries indistinct or absent',
#  '3 - Wood ring-porous',
#  '4 - Wood semi-ring-porous',
#  '5 - Wood diffuse-porous',
#  '6 - Vessels in tangential bands',
#  '7 - Vessels in diagonal and / or radial pattern',
#  '8 - Vessels in dendritic pattern',
#  '9 - Vessels exclusively solitary (90% or more)',
#  '10 - Vessels in radial multiples of 4 or more common',
#  '11 - Vessel clusters common',
#  '12MH - Solitary vessel outline angular',
#  '13 - Simple perforation plates',
#  '14 - Scalariform perforation plates',
#  '15 - Scalariform perforation plates with <= 10 bars',
#  '16 - Scalariform perforation plates with 10 - 20 bars',
#  '17 - Scalariform perforation plates with 20 - 40 bars',
#  '18 - Scalariform perforation plates with >= 40 bars',
#  '19MH - Reticulate, foraminate, and / or other types of multiple perforation plates',
#  '20 - Intervessel pits scalariform',
#  '21 - Intervessel pits opposite',
#  '22 - Intervessel pits alternate',
#  '23MH - Shape of alternate pits polygonal',
#  '24 - Minute - <= 4 Âµm',
#  '25MH - Small - 4 - 7 Âµm',
#  '26MH - Medium - 7 - 10 Âµm',
#  '27 - Large - >= 10 Âµm',
#  '29MH - Vestured pits',
#  '30 - Vessel-ray pits with distinct borders; similar to intervessel pits in size and shape throughout the ray cell',
#  '31MH - Vessel-ray pits with much reduced borders to apparently simple: pits rounded or angular',
#  '32MH - Vessel-ray pits with much reduced borders to apparently simple: pits horizontal (scalariform, gash-like) to vertical (palisade)',
#  '33MH - Vessel-ray pits of two distinct sizes or types in the same ray cell',
#  '34MH - Vessel-ray pits unilaterally compound and coarse (over 10 Âµm)',
#  '35MH - Vessel-ray pits restricted to marginal rows',
#  '36 - Helical thickenings in vessel elements present',
#  '37MH - Helical thickenings throughout body of vessel element',
#  '38MH - Helical thickenings only in vessel element tails',
#  '39MH - Helical thickenings only in narrower vessel elements',
#  '40 - <= 50 Âµm',
#  '41 - 50 - 100 Âµm',
#  '42 - 100 - 200 Âµm',
#  '43 - >= 200 Âµm',
#  '45MH - Vessels of two distinct diameter classes, wood not ring-porous',
#  '46 - <= 5 vessels per square millimetre',
#  '47 - 5 - 20 vessels per square millimetre',
#  '48 - 20 - 40 vessels per square millimetre',
#  '49 - 40 - 100 vessels per square millimetre',
#  '50 - >= 100 vessels per square millimetre',
#  '52 - <= 350 Âµm',
#  '53 - 350 - 800 Âµm',
#  '54 - >= 800 Âµm',
#  '56 - Tyloses common',
#  '57MH - Tyloses sclerotic',
#  '58MH - Gums and other deposits in heartwood vessels',
#  '59MH - Wood vesselless',
#  '60 - Vascular / vasicentric tracheids present',
#  '61 - Fibres with simple to minutely bordered pits',
#  '62 - Fibres with distinctly bordered pits',
#  '63MH - Fibre pits common in both radial and tangential walls',
#  '64MH - Helical thickenings in ground tissue fibres',
#  '65 - Septate fibres present',
#  '66MH - Non-septate fibres present',
#  '67MH - Parenchyma-like fibre bands alternating with ordinary fibres',
#  '68MH - Fibres very thin-walled',
#  '69MH - Fibres thin- to thick-walled',
#  '70MH - Fibres very thick-walled',
#  '71MH - <= 900 Âµm',
#  '72MH - 900-1600 Âµm',
#  '73MH - >= 1600 Âµm',
#  '75 - Axial parenchyma absent or extremely rare',
#  '76 - Axial parenchyma diffuse',
#  '77 - Axial parenchyma diffuse-in-aggregates',
#  '78 - Axial parenchyma scanty paratracheal',
#  '79 - Axial parenchyma vasicentric',
#  '80 - Axial parenchyma aliform',
#  '81MH - Axial parenchyma lozenge-aliform',
#  '82MH - Axial parenchyma winged-aliform',
#  '83 - Axial parenchyma confluent',
#  '84 - Axial parenchyma unilateral paratracheal',
#  '85 - Axial parenchyma bands more than three cells wide',
#  '86 - Axial parenchyma in narrow bands or lines up to three cells wide',
#  '87MH - Axial parenchyma reticulate',
#  '88MH - Axial parenchyma scalariform',
#  '89 - Axial parenchyma in marginal or in seemingly marginal bands',
#  '90MH - Fusiform parenchyma cells',
#  '91MH - Two cells per parenchyma strand',
#  '92MH - Four (3-4) cells per parenchyma strand',
#  '93MH - Eight (5-8) cells per parenchyma strand',
#  '94MH - Over eight cells per parenchyma strand',
#  '95MH - Unlignified parenchyma',
#  '96 - Rays exclusively uniseriate',
#  '97 - Ray width 1 to 3 cells',
#  '98 - Larger rays commonly 4 - to 10 seriate',
#  '99 - Larger rays commonly > 10-seriate',
#  '100 - Rays with multiseriate portion(s) as wide as uniseriate portions',
#  '101 - Aggregate rays',
#  '102 - Ray height > 1 mm',
#  '103 - Rays of two distinct sizes',
#  '104 - All ray cells procumbent',
#  '105 - All ray cells upright and / or square',
#  '106 - Body ray cells procumbent with one row of upright and / or square marginal cells',
#  '107 - Body ray cells procumbent with mostly 2-4 rows of upright and / or square marginal cells',
#  '108 - Body ray cells procumbent with over 4 rows of upright and / or square marginal cells',
#  '109MH - Rays with procumbent, square and upright cells mixed throughout the ray',
#  '110 - Sheath cells',
#  '111 - Tile cells',
#  '112MH - Perforated ray cells',
#  '113MH - Disjunctive ray parenchyma cell walls',
#  '114 - <= 4 / mm',
#  '115 - 4-12 / mm',
#  '116 - >= 12 /mm',
#  '117MH - Wood rayless',
#  '118MH - All rays storied',
#  '119MH - Low rays storied, high rays non-storied.',
#  '120 - Axial parenchyma and / or vessel elements storied',
#  '121MH - Fibres storied',
#  '122MH - Rays and / or axial elements irregularly storied',
#  '124 - Oil and / or mucilage cells associated with ray parenchyma',
#  '125 - Oil and / or mucilage cells associated with axial parenchyma',
#  '126 - Oil and / or mucilage cells present among fibres',
#  '127MH - Axial canals in long tangential lines',
#  '128MH - Axial canals in short tangential lines',
#  '129MH - Axial canals diffuse',
#  '130 - Radial canals',
#  '131 - Intercellular canals of traumatic origin',
#  '132MH - Laticifers or tanniniferous tubes',
#  '133MH - Included phloem, concentric',
#  '134MH - Included phloem, diffuse',
#  '135MH - Other cambial variants',
#  '136 - Prismatic crystals present',
#  '137 - Prismatic crystals in upright and / or square ray cells',
#  '138 - Prismatic crystals in procumbent ray cells',
#  '139MH - Prismatic crystals in radial alignment in procumbent ray cells',
#  '140MH - Prismatic crystals in chambered upright and / or square ray cells',
#  '141 - Prismatic crystals in non-chambered axial parenchyma cells',
#  '142 - Prismatic crystals in chambered axial parenchyma cells',
#  '143MH - Prismatic crystals in fibres',
#  '144MH - Druses present',
#  '145MH - Druses in ray parenchyma cells',
#  '146MH - Druses in axial parenchyma cells',
#  '147MH - Druses in fibres',
#  '148MH - Druses in chambered cells',
#  '149MH - Raphides',
#  '150MH - Acicular crystals',
#  '151MH - Styloids and / or elongate crystals',
#  '152MH - Crystals of other shapes (mostly small)',
#  '153MH - Crystal sand',
#  '154MH - More than one crystal of about the same size per cell or chamber',
#  '155MH - Two distinct sizes of crystals per cell or chamber',
#  '156 - Crystals in enlarged cells',
#  '157MH - Crystals in tyloses',
#  '158MH - Cystoliths',
#  '159MH - Silica bodies present',
#  '160MH - Silica bodies in ray cells',
#  '161MH - Silica bodies in axial parenchyma cells',
#  '162MH - Silica bodies in fibres',
#  '163MH - Vitreous silica',
#  '164 - Europe and temperate Asia (Brazier and Franklin region 75)',
#  '165 - Europe, excluding Mediterranean',
#  '166 - Mediterranean including Northern Africa and Middle East',
#  '167 - Temperate Asia (China), Japan, Russia',
#  '168 - Central South Asia (Brazier and Franklin region 75)',
#  '169MH - India, Pakistan, Sri Lanka',
#  '170MH - Burma',
#  '171 - Southeast Asia and Pacific (Brazier and Franklin region 76)',
#  '172MH - Thailand, Laos, Vietnam, Cambodia (Indochina)',
#  '173MH - Indomalesia: Indonesia, Philippines, Malaysia, Brunei, Papua, New Guinea, and Solomon Islands',
#  '174MH - Pacific Islands (including New Caledonia, Samoa, Hawaii, and Fiji)',
#  '175 - Australia and New Zealand (Brazier and Franklin region 77)',
#  '176MH - Australia',
#  '177MH - New Zealand',
#  '178 - Tropical mainland Africa and adjacent islands (Brazier and Franklin region 78)',
#  '179MH - Tropical Africa',
#  '180MH - Madagascar & Mauritius, RÃ©union & Comores',
#  '181 - Southern Africa (south of the Tropic of Capricorn) (Brazier and Franklin region 79)',
#  '182 - North America, north of Mexico (Brazier and Franklin region 80)',
#  '183 - Neotropics and temperate Brazil (Brazier and Franklin region 81)',
#  '184 - Mexico and Central America',
#  '185 - Carribean',
#  '186 - Tropical South America',
#  '187 - Southern Brazil',
#  '188 - Temperate South America including Argentina, Chile, Uruguay, and S. Paraguay (Brazier and Franklin region 82)',
#  '189MH - Tree',
#  '190MH - Shrub',
#  '191MH - Vine / liana',
#  '192MH - Wood of commercial importance',
#  '193MH - Basic specific gravity low, <= 0.40',
#  '194MH - Basic specific gravity medium, 0.40-0.75',
#  '195MH - Basic specific gravity high, >= 0.75',
#  '196MH - Heartwood colour darker than sapwood colour',
#  '197MH - Heartwood basically brown or shades of brown',
#  '198MH - Heartwood basically red or shades of red',
#  '199MH - Heartwood basically yellow or shades of yellow',
#  '200MH - Heartwood basically white to grey',
#  '201MH - Heartwood with streaks',
#  '202MH - Heartwood not as above',
#  '203MH - Distinct odour',
#  '204MH - Heartwood flourescent',
#  '205MH - Water extract fluorescent',
#  '206MH - Water extract basically colourless to brown or shades of brown',
#  '207MH - Water extract basically red or shades of red',
#  '208MH - Water extract basically yellow or shades of yellow',
#  '209MH - Water extract not as above',
#  '210MH - Ethanol extract fluorescent',
#  '211MH - Ethanol extract basically colourless to brown or shades of brown',
#  '212MH - Ethanol extract basically red or shades of red',
#  '213MH - Ethanol extract basically yellow or shades of yellow',
#  '214MH - Ethanol extract not as above',
#  '215MH - Froth test positive',
#  '216MH - Chrome Azurol-S test positive',
#  '217MH - Splinter burns to charcoal',
#  '218MH - Splinter burns to a full ash: Colour of ash bright white',
#  '219MH - Splinter burns to a full ash: Colour of ash yellow-brown',
#  '220MH - Splinter burns to a full ash: Colour of ash other than above',
#  '221MH - Splinter burns to a partial ash',
#  '300FH - Vessel-ray pits with much reduced borders to apparently simple',
#  '301FH - Banded',
#  '302FH - Rays heterocellular',
#  '303FH - Rays storied',
#  '304FH - Oil / mucilage cells present',
#  '305FH - Axial canals, normal',
#  '306FH - Included phloem',
#  '307FH - In ray cells',
#  '308FH - In axial parenchyma cells',
#  '309FH - Cretaceous',
#  '310FH - Aptian - Albian',
#  '311FH - Cenomanian - Turonian',
#  '312FH - Campanian - Maastrichtian',
#  '313FH - Paleocene',
#  '314FH - Lower',
#  '315FH - Middle',
#  '316FH - Upper',
#  '317FH - Eocene',
#  '318FH - Lower',
#  '319FH - Middle',
#  '320FH - Upper',
#  '321FH - Oligocene',
#  '322FH - Lower',
#  '323FH - Middle',
#  '324FH - Upper',
#  '325FH - Miocene',
#  '326FH - Lower',
#  '327FH - Middle',
#  '328FH - Upper',
#  '329FH - Pliocene',
#  '330FH - Lower',
#  '331FH - Middle',
#  '332FH - Upper',
#  '333FH - Small complete axis, twig, branch']

# %%
vector = []
for row in df_iawa.index:
    data = []
    for column in list(df_iawa.columns[1:]):
        data.append(df_iawa[column][row])
    vector.append(data)

# %%
iawa_feature_df = pd.read_csv("hardwood_features.csv", encoding="UTF-8", sep=";")
iawa_feature_df["hardwood_number"] = iawa_feature_df["hardwood_number"].fillna(-1)
iawa_feature_df["softwood_number"] = iawa_feature_df["softwood_number"].fillna(-1)
iawa_feature_df["bart_number"] = iawa_feature_df["bart_number"].fillna(-1)
iawa_feature_df["feature_group"] = iawa_feature_df["feature_group"].fillna(-1)
iawa_feature_df["feature_subgroup"] = iawa_feature_df["feature_subgroup"].fillna(-1)
iawa_feature_df = iawa_feature_df.astype({'hardwood_number': 'int32', 'softwood_number':'int32', 'bart_number':'int32'})

# %%
equivalence = dict()
direct_parent = dict()
data = []
label = ["feature_id", "parent_id", "feature_label", "definition", "author", "collection", "number_collection"]
for row in iawa_feature_df.index:
    equivalence[iawa_feature_df["feature_label"][row]] = iawa_feature_df["feature_id"][row]

for row in iawa_feature_df.index:
    group, subgroup = "", ""
    
    if iawa_feature_df["feature_group"][row] != -1:
        group = equivalence[iawa_feature_df["feature_group"][row]]
        
    if iawa_feature_df["feature_subgroup"][row] != -1:
        subgroup = equivalence[iawa_feature_df["feature_subgroup"][row]]

    
    feature_id = iawa_feature_df["feature_id"][row]
    author = iawa_feature_df["author"][row]
    
    if not feature_id in direct_parent.keys():
        direct_parent[feature_id] = subgroup if subgroup != "" else group if group != "" else ""
    if not subgroup in direct_parent.keys():
        direct_parent[subgroup] = group if subgroup != "" and group != "" else ""
    direct_parent[group] = ""
    
    parent_id = direct_parent[iawa_feature_df["feature_id"][row]]
    if not iawa_feature_df["hardwood_number"][row] == -1:
        feature_number = iawa_feature_df["hardwood_number"][row]
        collection = "Hardwood"
        data.append([feature_id, parent_id, iawa_feature_df["feature_label"][row], iawa_feature_df["definition"][row], iawa_feature_df["author"][row], collection, feature_number])
    if not iawa_feature_df["softwood_number"][row] == -1:
        feature_number = iawa_feature_df["softwood_number"][row]
        collection = "Softwood"
        data.append([feature_id, parent_id, iawa_feature_df["feature_label"][row], iawa_feature_df["definition"][row], iawa_feature_df["author"][row],collection, feature_number])
    if not iawa_feature_df["bart_number"][row] == -1:
        feature_number = iawa_feature_df["bart_number"][row]
        collection = "Bark"
        data.append([feature_id, parent_id, iawa_feature_df["feature_label"][row], iawa_feature_df["definition"][row], iawa_feature_df["author"][row],collection, feature_number])

    if iawa_feature_df["feature_group"][row] == -1 and iawa_feature_df["feature_subgroup"][row] == -1:
        feature_number = ""
        collection = ""
        data.append([feature_id, parent_id, iawa_feature_df["feature_label"][row], iawa_feature_df["definition"][row], iawa_feature_df["author"][row],collection, feature_number])
    
result_df = pd.DataFrame(data, columns=label)
result_df.to_csv("feature_list.csv", index=False, encoding="utf-8", sep=";")

# %%
df_iawa = pd.read_csv("generated_iawa.csv", sep=";", header=0, encoding="utf-8")
df_cepam = pd.read_csv("generated_cepam.csv", sep=";", header=0, encoding="utf-8")

# %%
data = []
label = ["sample_id", "taxon_id", "collection", "id_feature", "feature_value", "FOI", "original_data"]
feature_value = {3: "IFV-2", 2: "IFV-3", 1 : "IFV-4", 0: ""}
sample_id = 0
for row in df_iawa.index:
    sample_id += 1
    taxon_id = df_iawa["accepted_id"][row]
    collection = "Inside Wood"
    original_value = df_iawa["InsideWood_line"][row]
    
    for col_name in df_iawa.columns[7:]:
        feature_number = col_name.replace("MH -", " -").replace("Â", "").split("-")[0]
        if df_iawa[col_name][row] == 0:
            continue
        feature_id = iawa_feature_df[iawa_feature_df["hardwood_number"] == int(feature_number)]["feature_id"].values[0]
        data.append([f"IW-{sample_id}", taxon_id, "Inside Wood", feature_id, feature_value[df_iawa[col_name][row]],direct_parent[direct_parent[feature_id]], df_iawa["InsideWood_line"][row]])

generated_df = pd.DataFrame(data, columns=label)
generated_df.to_csv("insidewood.csv", encoding="utf-8", index=False, sep=";")

# %%
data = []
label = ["sample_id", "collected_at","taxon_id", "collection", "id_feature", "feature_value", "FOI", "original_data"]
feature_value = {3: "IFV-2", 2: "IFV-3", 1 : "IFV-4", 0: ""}
for row in df_cepam.index:
    taxon_id = df_cepam["accepted_id"][row]
    collection = "Inside Wood"
    
    for col_name in df_cepam.columns[11:]:
        feature_number = col_name.replace("MH -", " -").replace("Â", "").split("-")[0]
        if df_cepam[col_name][row] == 0:
            continue
        feature_id = iawa_feature_df[iawa_feature_df["hardwood_number"] == int(feature_number)]["feature_id"].values[0]
        original_str = f'{df_cepam["id_sample"][row]} - {df_cepam["cepam_family"][row]} { df_cepam["cepam_genus"][row]} {df_cepam["cepam_taxon"][row]}'
        data.append([df_cepam["id_sample"][row], df_cepam["collectedAt"][row], taxon_id, "SACHA", feature_id, feature_value[df_cepam[col_name][row]],direct_parent[direct_parent[feature_id]], original_str])

generated_df = pd.DataFrame(data, columns=label)
generated_df.to_csv("sacha.csv", encoding="utf-8", index=False, sep=";")
